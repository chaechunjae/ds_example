# %%
import seaborn as sns
sns.set_theme(style='whitegrid')
penguins = sns.load_dataset("penguins").dropna()
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.lineplot(data=penguins, x="body_mass_g", y="flipper_length_mm", errorbar=None)
# Out:
# <AxesSubplot: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.lineplot(data=penguins, x="body_mass_g", y="bill_length_mm", errorbar=None, hue="species")
# Out:
# <AxesSubplot: xlabel='body_mass_g', ylabel='bill_length_mm'>

# %%
sns.pointplot(data=penguins, x="species", y="body_mass_g", hue="sex", palette="Set2")
# Out:
# <AxesSubplot: xlabel='species', ylabel='body_mass_g'>

# %%
sns.histplot(data=penguins, x="bill_depth_mm", bins=30, hue="species", multiple="stack")
# Out:
# <AxesSubplot: xlabel='bill_depth_mm', ylabel='Count'>

# %%
sns.barplot(data=penguins, x="island", y="body_mass_g", hue="sex")
# Out:
# <AxesSubplot: xlabel='island', ylabel='body_mass_g'>

# %%
sns.countplot(data=penguins, y="sex")
# Out:
# <AxesSubplot: xlabel='count', ylabel='sex'>

# %%
sns.boxplot(data=penguins, x="species", y="body_mass_g")
# Out:
# <AxesSubplot: xlabel='species', ylabel='body_mass_g'>

# %%
sns.swarmplot(data=penguins, x="sex", y="flipper_length_mm", palette="summer")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_22564\3440668422.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(data=penguins, x="sex", y="flipper_length_mm", palette="summer")
# <AxesSubplot: xlabel='sex', ylabel='flipper_length_mm'>

# %%
sns.scatterplot(data=penguins, x="body_mass_g", y="flipper_length_mm", hue="species")
# Out:
# <AxesSubplot: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.corr()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_22564\140092681.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguins.corr()
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.228626           0.653096
# bill_depth_mm           -0.228626       1.000000          -0.577792
# flipper_length_mm        0.653096      -0.577792           1.000000
# body_mass_g              0.589451      -0.472016           0.872979
#
#                    body_mass_g
# bill_length_mm        0.589451
# bill_depth_mm        -0.472016
# flipper_length_mm     0.872979
# body_mass_g           1.000000

# %%
sns.heatmap(data=penguins.corr(), annot=True, cmap="Blues")
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_22564\644366900.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=penguins.corr(), annot=True, cmap="Blues")
# <AxesSubplot: >

# %%
sns.pairplot(data=penguins, hue="species")
